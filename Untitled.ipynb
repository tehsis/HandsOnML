# %%
print("hello world")
# Out:
# hello world

# %%
# !pip install --upgrade pandas matplotlib python-dateutil pipimport kagglehub scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 2.7 MB/s  0:00:03m 2.7 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 3.2 MB/s  0:00:11 eta 0:00:010:01:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn]0m 3/4 [scikit-learn]
# ...

# %%
import pandas as pd
import kagglehub
import matplotlib.pyplot as plt

# %%
# Download latest version
path = kagglehub.dataset_download("jockeroika/life-style-data")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/tehsis/.cache/kagglehub/datasets/jockeroika/life-style-data/versions/7

# %%
health = pd.read_csv("/home/tehsis/.cache/kagglehub/datasets/jockeroika/life-style-data/versions/7/Final_data.csv")

# %%
health.head()
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0  34.91    Male        65.27        1.62   188.58   157.65        69.05
# 1  23.37  Female        56.41        1.55   179.43   131.75        73.18
# 2  33.20  Female        58.98        1.67   175.04   123.95        54.96
# 3  38.69  Female        93.78        1.70   191.21   155.10        50.07
# 4  45.09    Male        52.42        1.88   193.58   152.88        70.84
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  ...  \
# 0                      1.00          1080.90     Strength  ...
# 1                      1.37          1809.91         HIIT  ...
# 2                      0.91           802.26       Cardio  ...
# 3                      1.10          1450.79         HIIT  ...
# 4                      1.08          1166.40     Strength  ...
#
#    cal_from_macros  pct_carbs  protein_per_kg   pct_HRR  pct_maxHR  \
# 0          2139.59   0.500432        1.624789  0.741237   0.835985
# ...

# %%
health.describe()
# Out:
#                 Age   Weight (kg)    Height (m)       Max_BPM       Avg_BPM  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean      38.851454     73.898832      1.723094    179.889702    143.704306
# std       12.114580     21.173010      0.127033     11.510805     14.267688
# min       18.000000     39.180000      1.490000    159.310000    119.070000
# 25%       28.170000     58.160000      1.620000    170.057500    131.220000
# 50%       39.865000     70.000000      1.710000    180.140000    142.990000
# 75%       49.630000     86.100000      1.800000    189.425000    156.060000
# max       59.670000    130.770000      2.010000    199.640000    169.840000
#
#         Resting_BPM  Session_Duration (hours)  Calories_Burned  \
# count  20000.000000              20000.000000     20000.000000
# mean      62.195813                  1.259446      1280.109601
# std        7.289351                  0.341336       502.228982
# ...

# %%
health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             20000 non-null  float64
#  1   Gender                          20000 non-null  object
#  2   Weight (kg)                     20000 non-null  float64
#  3   Height (m)                      20000 non-null  float64
#  4   Max_BPM                         20000 non-null  float64
#  5   Avg_BPM                         20000 non-null  float64
#  6   Resting_BPM                     20000 non-null  float64
#  7   Session_Duration (hours)        20000 non-null  float64
#  8   Calories_Burned                 20000 non-null  float64
#  9   Workout_Type                    20000 non-null  object
#  10  Fat_Percentage                  20000 non-null  float64
#  11  Water_Intake (liters)           20000 non-null  float64
# ...

# %%
health["Gender"].value_counts()
# Out:
# Gender
# Female    10028
# Male       9972
# Name: count, dtype: int64

# %%
health["Target Muscle Group"].value_counts()
# Out:
# Target Muscle Group
# Chest, Triceps                    602
# Biceps, Forearms                  598
# Upper Chest, Triceps              593
# Upper Back, Rear Deltoids         593
# Glutes, Hamstrings, Core          587
# Core, Obliques                    582
# Shoulders                         581
# Lower Abs, Hip Flexors            580
# Quadriceps                        580
# Full Body, Core, Shoulders        578
# Lower Back, Glutes                577
# Quadriceps, Hamstrings, Glutes    571
# Legs, Shoulders, Core             569
# Glutes, Hamstrings                569
# Obliques, Core                    565
# Core, Lower Back                  561
# Full Core                         560
# Legs, Core                        559
# Lower Chest, Triceps              557
# Back, Core, Shoulders             553
# Quadriceps, Glutes                553
# Core                              551
# Shoulders, Upper Back             549
# Core, Shoulders, Legs             546
# ...

# %%
health["Benefit"].value_counts()
# Out:
# Benefit
# Full body workout                                  445
# Targets biceps and forearms                        445
# Advanced core exercise                             441
# Targets obliques and improves core rotation        438
# Targets lower chest                                438
# Strengthens triceps and chest                      435
# Isolates and strengthens triceps                   433
# Improves posture and strengthens upper back        431
# Builds unilateral leg strength and balance         431
# Builds explosive upper body power                  431
# Strengthens back and improves posture              429
# Improves cardiovascular fitness                    429
# Improves balance and leg strength                  428
# Improves core stability                            427
# Improves core stability and balance                426
# Builds upper body strength                         422
# Builds back strength                               420
# ...

# %%
health["Workout"].value_counts()
# Out:
# Workout
# Leg press                      423
# Bird dog                       422
# Preacher curls                 413
# Decline dumbbell flyes         413
# Standing calf raises           404
# Incline dumbbell press         398
# Cable crossovers               396
# Crunches                       395
# Triceps dips                   394
# Face pulls                     393
# Dumbbell flyes                 391
# Wrist curl                     391
# Incline cable crossovers       390
# Skull crushers                 389
# Seated cable rows              389
# Hanging leg raises             388
# Russian twists                 387
# Plate pinch                    387
# Barbell squats                 386
# Bent-over lateral raises       385
# Bicep Curls                    385
# Triceps pushdowns              384
# Barbell rows                   384
# Barbell curls                  383
# Hammer curl                    382
# Leg curls                      382
# ...

# %%
plt.style.use("ggplot")

health.hist(bins=50, figsize=(50, 20))

plt.show()

# %%
health["pct_carbs"].pie()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_98684/2541884021.py in ?()
# ----> 1 health["pct_carbs"].pie()
#
# ~/workspace/mlcourse/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'pie'
